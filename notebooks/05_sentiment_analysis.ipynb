# %%
import polars as pl
import boto3
import sys
import os
import torch
import time

sys.path.append("../src")

# %%
from sentiment_analysis import (
    load_sentiment_model,
    get_sentiment,
    save_sentiment_checkpoint,
    merge_sentiment_checkpoints,
    merge_sentiment_with_summary
)

# %%
bucket = "amazon-electronics-dataset"

summarized_input = "s3://amazon-electronics-dataset/summarized_dataset/final_summarized_grouped_30700.csv"
sentiment_checkpoint_prefix = "s3://amazon-electronics-dataset/sentiment_checkpoints/"
sentiment_scores_output = "s3://amazon-electronics-dataset/sentiment_analysed_dataset/sentiment_scores_only.csv"
final_merged_output = "s3://amazon-electronics-dataset/sentiment_analysed_dataset/final_summarized_plus_sentiment.csv"

# %%
df_full = pl.read_csv(summarized_input)
print(df_full.shape)
df_full.head()
# Out:
# (31100, 11)
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ product_i ┆ all_revie ┆ all_user_ ┆ avg_ratin ┆ … ┆ oldest_re ┆ newest_re ┆ abstracte ┆ review_c │
# │ d         ┆ ws        ┆ summaries ┆ g         ┆   ┆ view_time ┆ view_time ┆ d_summary ┆ ount_rig │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ stamp     ┆ stamp     ┆ ---       ┆ ht       │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ i64       ┆ i64       ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ B00OHDONO ┆ i bought  ┆ Great MP3 ┆ null      ┆ … ┆ 142974720 ┆ 146629440 ┆ The       ┆ 42       │
# │ A         ┆ this mp3  ┆ with      ┆           ┆   ┆ 0         ┆ 0         ┆ agptek    ┆          │
# │           ┆ player to ┆ amazing   ┆           ┆   ┆           ┆           ┆ 2015 is a ┆          │
# │           ┆ us…       ┆ battery…  ┆           ┆   ┆           ┆           ┆ fantastic ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ …         ┆          │
# │ B01GHLYPW ┆ doesn t   ┆ Good      ┆ null      ┆ … ┆ 146880000 ┆ 153688320 ┆ Great     ┆ 48       │
# │ E         ┆ support   ┆ customer  ┆           ┆   ┆ 0         ┆ 0         ┆ deal      ┆          │
# │           ┆ 120hz     ┆ service   ┆           ┆   ┆           ┆           ┆ worked as ┆          │
# │           ┆ 1080p no… ┆ but prod… ┆           ┆   ┆           ┆           ┆ expected  ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ …         ┆          │
# │ B00F19Q3T ┆ the price ┆ love this ┆ null      ┆ … ┆ 138335040 ┆ 149627520 ┆ The price ┆ 58       │
# │ 2         ┆ is right  ┆ lens for  ┆           ┆   ┆ 0         ┆ 0         ┆ is right  ┆          │
# │           ┆ but i     ┆ my gopro. ┆           ┆   ┆           ┆           ┆ but i     ┆          │
# │           ┆ wish …    ┆  …        ┆           ┆   ┆           ┆           ┆ wish …    ┆          │
# │ B001584QQ ┆ one day i ┆ They      ┆ null      ┆ … ┆ 126230400 ┆ 152444160 ┆ One day i ┆ 42       │
# │ A         ┆ turned    ┆ worked    ┆           ┆   ┆ 0         ┆ 0         ┆ turned    ┆          │
# │           ┆ them to   ┆ great     ┆           ┆   ┆           ┆           ┆ them to   ┆          │
# │           ┆ put t…    ┆ until     ┆           ┆   ┆           ┆           ┆ put t…    ┆          │
# │           ┆           ┆ they b…   ┆           ┆   ┆           ┆           ┆           ┆          │
# │ B007PJ4PK ┆ i use the ┆ Fun       ┆ null      ┆ … ┆ 134066880 ┆ 147960000 ┆ I use the ┆ 82       │
# │ K         ┆ logitech  ┆ pattern,  ┆           ┆   ┆ 0         ┆ 0         ┆ logitech  ┆          │
# │           ┆ wireless  ┆ great     ┆           ┆   ┆           ┆           ┆ wireless  ┆          │
# │           ┆ ke…       ┆ keystroke ┆           ┆   ┆           ┆           ┆ ke…       ┆          │
# │           ┆           ┆ f…        ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df_full.filter(pl.col("abstracted_summary").is_null()).shape
# Out:
# (0, 11)

# %%
df_full.select(pl.col("product_id").n_unique())
# Out:
# shape: (1, 1)
# ┌────────────┐
# │ product_id │
# │ ---        │
# │ u32        │
# ╞════════════╡
# │ 31100      │
# └────────────┘

# %%
# Load the model
tokenizer, model, device = load_sentiment_model()
print("Model loaded!")
print("Using device:", device)
# Out:
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# 2025-11-27 19:33:12.273885: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764271992.289681    2822 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764271992.294643    2822 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-27 19:33:12.309994: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Model loaded!
# Using device: cuda

# %%
# Test sentiment on first sample

sample = df_full.row(0, named=True)

text = sample["abstracted_summary"]
pid = sample["product_id"]

print("Product ID:", pid)
print("\nABSTRACTED SUMMARY\n")
print(text)

# Run sentiment
label, score = get_sentiment(tokenizer, model, device, text)

print("\nSENTIMENT OUTPUT")
print("Sentiment Label:", label)
print("Sentiment Score:", score)
# Out:
# Product ID: B00OHDONOA
#
# ABSTRACTED SUMMARY
#
# The agptek 2015 is a fantastic tool for capturing the early phases of a songwriting work in progress .<n>The agptek 2015 makes excellent recordings and stores them in a very logical folder system . The agptek 2015 is an excellent mp3 player it enables setting up play lists .<n>i prefer to simply create a folder and drop a group of mp3 song files into that folder .<n>The agptek is feather light but seems well made and will likely stand up to normal use . mp3 player takes practice learning to work it but otherwise wonderful just needed something to play mp3 s while i work out perfect for that and added bonus is batteries stay charged a long time .<n>i found this one does what i want w o a hitch long battery life with a micro sd card slot negotiating the menu takes practice as it is not as intuitive as other players easy .
#
# SENTIMENT OUTPUT
# Sentiment Label: positive
# Sentiment Score: 0.9380781054496765

# %%
# Full sentiment loop with checkpoints

results = []
checkpoint_num = 1
start_time = time.time()

print("Starting SENTIMENT ANALYSIS")

for i, row in enumerate(df_full.iter_rows(named=True), start=1):

    pid = row["product_id"]
    text = row["abstracted_summary"]

    label, score = get_sentiment(tokenizer, model, device, text)

    results.append({
        "product_id": pid,
        "sentiment_label": label,
        "sentiment_score": score
    })

    if i % 100 == 0:
        batch_df = pl.DataFrame(results)
        save_sentiment_checkpoint(batch_df, checkpoint_num, bucket, sentiment_checkpoint_prefix)
        results = []
        checkpoint_num += 1
        print(f"Checkpoint saved at {i} products")

    if i % 500 == 0:
        elapsed = time.time() - start_time
        eta_hours = (elapsed / i) * (df_full.shape[0] - i) / 3600
        print(f"[Progress] {i}/{df_full.shape[0]} | ETA ~ {eta_hours:.2f} hours")

if results:
    batch_df = pl.DataFrame(results)
    save_sentiment_checkpoint(batch_df, checkpoint_num, bucket, sentiment_checkpoint_prefix)

print("Sentiment analysis completed.")
# Out:
# Starting SENTIMENT ANALYSIS
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_1.csv
# Checkpoint saved at 100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_2.csv
# Checkpoint saved at 200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_3.csv
# Checkpoint saved at 300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_4.csv
# Checkpoint saved at 400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_5.csv
# Checkpoint saved at 500 products
# [Progress] 500/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_6.csv
# Checkpoint saved at 600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_7.csv
# Checkpoint saved at 700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_8.csv
# Checkpoint saved at 800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_9.csv
# Checkpoint saved at 900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_10.csv
# Checkpoint saved at 1000 products
# [Progress] 1000/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_11.csv
# Checkpoint saved at 1100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_12.csv
# Checkpoint saved at 1200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_13.csv
# Checkpoint saved at 1300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_14.csv
# Checkpoint saved at 1400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_15.csv
# Checkpoint saved at 1500 products
# [Progress] 1500/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_16.csv
# Checkpoint saved at 1600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_17.csv
# Checkpoint saved at 1700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_18.csv
# Checkpoint saved at 1800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_19.csv
# Checkpoint saved at 1900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_20.csv
# Checkpoint saved at 2000 products
# [Progress] 2000/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_21.csv
# Checkpoint saved at 2100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_22.csv
# Checkpoint saved at 2200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_23.csv
# Checkpoint saved at 2300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_24.csv
# Checkpoint saved at 2400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_25.csv
# Checkpoint saved at 2500 products
# [Progress] 2500/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_26.csv
# Checkpoint saved at 2600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_27.csv
# Checkpoint saved at 2700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_28.csv
# Checkpoint saved at 2800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_29.csv
# Checkpoint saved at 2900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_30.csv
# Checkpoint saved at 3000 products
# [Progress] 3000/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_31.csv
# Checkpoint saved at 3100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_32.csv
# Checkpoint saved at 3200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_33.csv
# Checkpoint saved at 3300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_34.csv
# Checkpoint saved at 3400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_35.csv
# Checkpoint saved at 3500 products
# [Progress] 3500/31100 | ETA ~ 0.05 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_36.csv
# Checkpoint saved at 3600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_37.csv
# Checkpoint saved at 3700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_38.csv
# Checkpoint saved at 3800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_39.csv
# Checkpoint saved at 3900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_40.csv
# Checkpoint saved at 4000 products
# [Progress] 4000/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_41.csv
# Checkpoint saved at 4100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_42.csv
# Checkpoint saved at 4200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_43.csv
# Checkpoint saved at 4300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_44.csv
# Checkpoint saved at 4400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_45.csv
# Checkpoint saved at 4500 products
# [Progress] 4500/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_46.csv
# Checkpoint saved at 4600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_47.csv
# Checkpoint saved at 4700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_48.csv
# Checkpoint saved at 4800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_49.csv
# Checkpoint saved at 4900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_50.csv
# Checkpoint saved at 5000 products
# [Progress] 5000/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_51.csv
# Checkpoint saved at 5100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_52.csv
# Checkpoint saved at 5200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_53.csv
# Checkpoint saved at 5300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_54.csv
# Checkpoint saved at 5400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_55.csv
# Checkpoint saved at 5500 products
# [Progress] 5500/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_56.csv
# Checkpoint saved at 5600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_57.csv
# Checkpoint saved at 5700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_58.csv
# Checkpoint saved at 5800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_59.csv
# Checkpoint saved at 5900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_60.csv
# Checkpoint saved at 6000 products
# [Progress] 6000/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_61.csv
# Checkpoint saved at 6100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_62.csv
# Checkpoint saved at 6200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_63.csv
# Checkpoint saved at 6300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_64.csv
# Checkpoint saved at 6400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_65.csv
# Checkpoint saved at 6500 products
# [Progress] 6500/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_66.csv
# Checkpoint saved at 6600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_67.csv
# Checkpoint saved at 6700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_68.csv
# Checkpoint saved at 6800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_69.csv
# Checkpoint saved at 6900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_70.csv
# Checkpoint saved at 7000 products
# [Progress] 7000/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_71.csv
# Checkpoint saved at 7100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_72.csv
# Checkpoint saved at 7200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_73.csv
# Checkpoint saved at 7300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_74.csv
# Checkpoint saved at 7400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_75.csv
# Checkpoint saved at 7500 products
# [Progress] 7500/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_76.csv
# Checkpoint saved at 7600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_77.csv
# Checkpoint saved at 7700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_78.csv
# Checkpoint saved at 7800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_79.csv
# Checkpoint saved at 7900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_80.csv
# Checkpoint saved at 8000 products
# [Progress] 8000/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_81.csv
# Checkpoint saved at 8100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_82.csv
# Checkpoint saved at 8200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_83.csv
# Checkpoint saved at 8300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_84.csv
# Checkpoint saved at 8400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_85.csv
# Checkpoint saved at 8500 products
# [Progress] 8500/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_86.csv
# Checkpoint saved at 8600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_87.csv
# Checkpoint saved at 8700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_88.csv
# Checkpoint saved at 8800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_89.csv
# Checkpoint saved at 8900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_90.csv
# Checkpoint saved at 9000 products
# [Progress] 9000/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_91.csv
# Checkpoint saved at 9100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_92.csv
# Checkpoint saved at 9200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_93.csv
# Checkpoint saved at 9300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_94.csv
# Checkpoint saved at 9400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_95.csv
# Checkpoint saved at 9500 products
# [Progress] 9500/31100 | ETA ~ 0.04 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_96.csv
# Checkpoint saved at 9600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_97.csv
# Checkpoint saved at 9700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_98.csv
# Checkpoint saved at 9800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_99.csv
# Checkpoint saved at 9900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_100.csv
# Checkpoint saved at 10000 products
# [Progress] 10000/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_101.csv
# Checkpoint saved at 10100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_102.csv
# Checkpoint saved at 10200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_103.csv
# Checkpoint saved at 10300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_104.csv
# Checkpoint saved at 10400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_105.csv
# Checkpoint saved at 10500 products
# [Progress] 10500/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_106.csv
# Checkpoint saved at 10600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_107.csv
# Checkpoint saved at 10700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_108.csv
# Checkpoint saved at 10800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_109.csv
# Checkpoint saved at 10900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_110.csv
# Checkpoint saved at 11000 products
# [Progress] 11000/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_111.csv
# Checkpoint saved at 11100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_112.csv
# Checkpoint saved at 11200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_113.csv
# Checkpoint saved at 11300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_114.csv
# Checkpoint saved at 11400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_115.csv
# Checkpoint saved at 11500 products
# [Progress] 11500/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_116.csv
# Checkpoint saved at 11600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_117.csv
# Checkpoint saved at 11700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_118.csv
# Checkpoint saved at 11800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_119.csv
# Checkpoint saved at 11900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_120.csv
# Checkpoint saved at 12000 products
# [Progress] 12000/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_121.csv
# Checkpoint saved at 12100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_122.csv
# Checkpoint saved at 12200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_123.csv
# Checkpoint saved at 12300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_124.csv
# Checkpoint saved at 12400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_125.csv
# Checkpoint saved at 12500 products
# [Progress] 12500/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_126.csv
# Checkpoint saved at 12600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_127.csv
# Checkpoint saved at 12700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_128.csv
# Checkpoint saved at 12800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_129.csv
# Checkpoint saved at 12900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_130.csv
# Checkpoint saved at 13000 products
# [Progress] 13000/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_131.csv
# Checkpoint saved at 13100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_132.csv
# Checkpoint saved at 13200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_133.csv
# Checkpoint saved at 13300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_134.csv
# Checkpoint saved at 13400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_135.csv
# Checkpoint saved at 13500 products
# [Progress] 13500/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_136.csv
# Checkpoint saved at 13600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_137.csv
# Checkpoint saved at 13700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_138.csv
# Checkpoint saved at 13800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_139.csv
# Checkpoint saved at 13900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_140.csv
# Checkpoint saved at 14000 products
# [Progress] 14000/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_141.csv
# Checkpoint saved at 14100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_142.csv
# Checkpoint saved at 14200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_143.csv
# Checkpoint saved at 14300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_144.csv
# Checkpoint saved at 14400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_145.csv
# Checkpoint saved at 14500 products
# [Progress] 14500/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_146.csv
# Checkpoint saved at 14600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_147.csv
# Checkpoint saved at 14700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_148.csv
# Checkpoint saved at 14800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_149.csv
# Checkpoint saved at 14900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_150.csv
# Checkpoint saved at 15000 products
# [Progress] 15000/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_151.csv
# Checkpoint saved at 15100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_152.csv
# Checkpoint saved at 15200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_153.csv
# Checkpoint saved at 15300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_154.csv
# Checkpoint saved at 15400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_155.csv
# Checkpoint saved at 15500 products
# [Progress] 15500/31100 | ETA ~ 0.03 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_156.csv
# Checkpoint saved at 15600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_157.csv
# Checkpoint saved at 15700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_158.csv
# Checkpoint saved at 15800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_159.csv
# Checkpoint saved at 15900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_160.csv
# Checkpoint saved at 16000 products
# [Progress] 16000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_161.csv
# Checkpoint saved at 16100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_162.csv
# Checkpoint saved at 16200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_163.csv
# Checkpoint saved at 16300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_164.csv
# Checkpoint saved at 16400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_165.csv
# Checkpoint saved at 16500 products
# [Progress] 16500/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_166.csv
# Checkpoint saved at 16600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_167.csv
# Checkpoint saved at 16700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_168.csv
# Checkpoint saved at 16800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_169.csv
# Checkpoint saved at 16900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_170.csv
# Checkpoint saved at 17000 products
# [Progress] 17000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_171.csv
# Checkpoint saved at 17100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_172.csv
# Checkpoint saved at 17200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_173.csv
# Checkpoint saved at 17300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_174.csv
# Checkpoint saved at 17400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_175.csv
# Checkpoint saved at 17500 products
# [Progress] 17500/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_176.csv
# Checkpoint saved at 17600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_177.csv
# Checkpoint saved at 17700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_178.csv
# Checkpoint saved at 17800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_179.csv
# Checkpoint saved at 17900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_180.csv
# Checkpoint saved at 18000 products
# [Progress] 18000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_181.csv
# Checkpoint saved at 18100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_182.csv
# Checkpoint saved at 18200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_183.csv
# Checkpoint saved at 18300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_184.csv
# Checkpoint saved at 18400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_185.csv
# Checkpoint saved at 18500 products
# [Progress] 18500/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_186.csv
# Checkpoint saved at 18600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_187.csv
# Checkpoint saved at 18700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_188.csv
# Checkpoint saved at 18800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_189.csv
# Checkpoint saved at 18900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_190.csv
# Checkpoint saved at 19000 products
# [Progress] 19000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_191.csv
# Checkpoint saved at 19100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_192.csv
# Checkpoint saved at 19200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_193.csv
# Checkpoint saved at 19300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_194.csv
# Checkpoint saved at 19400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_195.csv
# Checkpoint saved at 19500 products
# [Progress] 19500/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_196.csv
# Checkpoint saved at 19600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_197.csv
# Checkpoint saved at 19700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_198.csv
# Checkpoint saved at 19800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_199.csv
# Checkpoint saved at 19900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_200.csv
# Checkpoint saved at 20000 products
# [Progress] 20000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_201.csv
# Checkpoint saved at 20100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_202.csv
# Checkpoint saved at 20200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_203.csv
# Checkpoint saved at 20300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_204.csv
# Checkpoint saved at 20400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_205.csv
# Checkpoint saved at 20500 products
# [Progress] 20500/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_206.csv
# Checkpoint saved at 20600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_207.csv
# Checkpoint saved at 20700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_208.csv
# Checkpoint saved at 20800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_209.csv
# Checkpoint saved at 20900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_210.csv
# Checkpoint saved at 21000 products
# [Progress] 21000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_211.csv
# Checkpoint saved at 21100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_212.csv
# Checkpoint saved at 21200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_213.csv
# Checkpoint saved at 21300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_214.csv
# Checkpoint saved at 21400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_215.csv
# Checkpoint saved at 21500 products
# [Progress] 21500/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_216.csv
# Checkpoint saved at 21600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_217.csv
# Checkpoint saved at 21700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_218.csv
# Checkpoint saved at 21800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_219.csv
# Checkpoint saved at 21900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_220.csv
# Checkpoint saved at 22000 products
# [Progress] 22000/31100 | ETA ~ 0.02 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_221.csv
# Checkpoint saved at 22100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_222.csv
# Checkpoint saved at 22200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_223.csv
# Checkpoint saved at 22300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_224.csv
# Checkpoint saved at 22400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_225.csv
# Checkpoint saved at 22500 products
# [Progress] 22500/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_226.csv
# Checkpoint saved at 22600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_227.csv
# Checkpoint saved at 22700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_228.csv
# Checkpoint saved at 22800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_229.csv
# Checkpoint saved at 22900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_230.csv
# Checkpoint saved at 23000 products
# [Progress] 23000/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_231.csv
# Checkpoint saved at 23100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_232.csv
# Checkpoint saved at 23200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_233.csv
# Checkpoint saved at 23300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_234.csv
# Checkpoint saved at 23400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_235.csv
# Checkpoint saved at 23500 products
# [Progress] 23500/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_236.csv
# Checkpoint saved at 23600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_237.csv
# Checkpoint saved at 23700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_238.csv
# Checkpoint saved at 23800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_239.csv
# Checkpoint saved at 23900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_240.csv
# Checkpoint saved at 24000 products
# [Progress] 24000/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_241.csv
# Checkpoint saved at 24100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_242.csv
# Checkpoint saved at 24200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_243.csv
# Checkpoint saved at 24300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_244.csv
# Checkpoint saved at 24400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_245.csv
# Checkpoint saved at 24500 products
# [Progress] 24500/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_246.csv
# Checkpoint saved at 24600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_247.csv
# Checkpoint saved at 24700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_248.csv
# Checkpoint saved at 24800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_249.csv
# Checkpoint saved at 24900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_250.csv
# Checkpoint saved at 25000 products
# [Progress] 25000/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_251.csv
# Checkpoint saved at 25100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_252.csv
# Checkpoint saved at 25200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_253.csv
# Checkpoint saved at 25300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_254.csv
# Checkpoint saved at 25400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_255.csv
# Checkpoint saved at 25500 products
# [Progress] 25500/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_256.csv
# Checkpoint saved at 25600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_257.csv
# Checkpoint saved at 25700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_258.csv
# Checkpoint saved at 25800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_259.csv
# Checkpoint saved at 25900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_260.csv
# Checkpoint saved at 26000 products
# [Progress] 26000/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_261.csv
# Checkpoint saved at 26100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_262.csv
# Checkpoint saved at 26200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_263.csv
# Checkpoint saved at 26300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_264.csv
# Checkpoint saved at 26400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_265.csv
# Checkpoint saved at 26500 products
# [Progress] 26500/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_266.csv
# Checkpoint saved at 26600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_267.csv
# Checkpoint saved at 26700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_268.csv
# Checkpoint saved at 26800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_269.csv
# Checkpoint saved at 26900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_270.csv
# Checkpoint saved at 27000 products
# [Progress] 27000/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_271.csv
# Checkpoint saved at 27100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_272.csv
# Checkpoint saved at 27200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_273.csv
# Checkpoint saved at 27300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_274.csv
# Checkpoint saved at 27400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_275.csv
# Checkpoint saved at 27500 products
# [Progress] 27500/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_276.csv
# Checkpoint saved at 27600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_277.csv
# Checkpoint saved at 27700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_278.csv
# Checkpoint saved at 27800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_279.csv
# Checkpoint saved at 27900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_280.csv
# Checkpoint saved at 28000 products
# [Progress] 28000/31100 | ETA ~ 0.01 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_281.csv
# Checkpoint saved at 28100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_282.csv
# Checkpoint saved at 28200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_283.csv
# Checkpoint saved at 28300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_284.csv
# Checkpoint saved at 28400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_285.csv
# Checkpoint saved at 28500 products
# [Progress] 28500/31100 | ETA ~ 0.00 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_286.csv
# Checkpoint saved at 28600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_287.csv
# Checkpoint saved at 28700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_288.csv
# Checkpoint saved at 28800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_289.csv
# Checkpoint saved at 28900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_290.csv
# Checkpoint saved at 29000 products
# [Progress] 29000/31100 | ETA ~ 0.00 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_291.csv
# Checkpoint saved at 29100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_292.csv
# Checkpoint saved at 29200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_293.csv
# Checkpoint saved at 29300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_294.csv
# Checkpoint saved at 29400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_295.csv
# Checkpoint saved at 29500 products
# [Progress] 29500/31100 | ETA ~ 0.00 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_296.csv
# Checkpoint saved at 29600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_297.csv
# Checkpoint saved at 29700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_298.csv
# Checkpoint saved at 29800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_299.csv
# Checkpoint saved at 29900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_300.csv
# Checkpoint saved at 30000 products
# [Progress] 30000/31100 | ETA ~ 0.00 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_301.csv
# Checkpoint saved at 30100 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_302.csv
# Checkpoint saved at 30200 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_303.csv
# Checkpoint saved at 30300 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_304.csv
# Checkpoint saved at 30400 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_305.csv
# Checkpoint saved at 30500 products
# [Progress] 30500/31100 | ETA ~ 0.00 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_306.csv
# Checkpoint saved at 30600 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_307.csv
# Checkpoint saved at 30700 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_308.csv
# Checkpoint saved at 30800 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_309.csv
# Checkpoint saved at 30900 products
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_310.csv
# Checkpoint saved at 31000 products
# [Progress] 31000/31100 | ETA ~ 0.00 hours
# [Checkpoint] Uploaded → s3://amazon-electronics-dataset/sentiment_checkpoints/sentiment_checkpoint_311.csv
# Checkpoint saved at 31100 products
# Sentiment analysis completed.

# %%
# Merge sentiment files

sentiment_scores = merge_sentiment_checkpoints(
    bucket=bucket,
    prefix=sentiment_checkpoint_prefix,
    output_path=sentiment_scores_output
)

sentiment_scores.head()
# Out:
# [Final Merge] Created sentiment_scores_only.csv
# shape: (5, 3)
# ┌────────────┬─────────────────┬─────────────────┐
# │ product_id ┆ sentiment_label ┆ sentiment_score │
# │ ---        ┆ ---             ┆ ---             │
# │ str        ┆ str             ┆ f64             │
# ╞════════════╪═════════════════╪═════════════════╡
# │ B00OHDONOA ┆ positive        ┆ 0.938078        │
# │ B01GHLYPWE ┆ neutral         ┆ 0.365432        │
# │ B00F19Q3T2 ┆ positive        ┆ 0.829172        │
# │ B001584QQA ┆ neutral         ┆ 0.482159        │
# │ B007PJ4PKK ┆ positive        ┆ 0.765428        │
# └────────────┴─────────────────┴─────────────────┘

# %%
# Merge sentiment back into full dataset

df_final = merge_sentiment_with_summary(df_full, sentiment_scores)
df_final.head()
print(df_final.shape)
# Out:
# (31100, 13)

# %%
# Save final merged dataset to S3

local_final = "/tmp/final_summarized_plus_sentiment.csv"
df_final.write_csv(local_final)

s3 = boto3.client("s3")
s3.upload_file(local_final, bucket, final_merged_output.replace(f"s3://{bucket}/",""))

print("FINAL DATASET SAVED", final_merged_output)
# Out:
# FINAL DATASET SAVED s3://amazon-electronics-dataset/sentiment_analysed_dataset/final_summarized_plus_sentiment.csv
