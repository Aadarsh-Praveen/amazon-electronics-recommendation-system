# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in /opt/conda/lib/python3.12/site-packages (1.35.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /opt/conda/lib/python3.12/site-packages (from polars) (1.35.2)

# %%
import polars as pl
import pandas as pd
import sys

sys.path.append("../src")
from preprocess import clean_text, flatten_style

# %%
#Load raw JSON
BUCKET = "amazon-electronics-dataset"
KEY = "Raw_Dataset/Electronics_5.json"

df_lazy = pl.scan_ndjson(f"s3://{BUCKET}/{KEY}")
df_lazy
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20250203.1708)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="537pt" height="49pt"
#  viewBox="0.00 0.00 537.00 49.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 45)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-45 533,-45 533,4 -4,4"/>
# <!-- p1 -->
# <g id="node1" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="529,-41 0,-41 0,0 529,0 529,-41"/>
# <text text-anchor="middle" x="264.5" y="-23.7" font-family="Monospace" font-size="14.00">NDJson SCAN [s3://amazon&#45;electronics&#45;dataset/Raw_Dataset/Electronics_5.json]</text>
# <text text-anchor="middle" x="264.5" y="-7.95" font-family="Monospace" font-size="14.00">π */12;</text>
# </g>
# </g>
# </svg>

# %%
#Selecting required columns
df_lazy = df_lazy.select([
    "reviewerID",
    "asin",
    "reviewText",
    "summary",
    "overall",
    "vote",
    "verified",
    "reviewTime",
    "unixReviewTime",
    "style",
    "image",
    "reviewerName"
])

# %%
df = df_lazy.collect()
df.head()
# Out:
# shape: (5, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ reviewerI ┆ asin      ┆ reviewTex ┆ summary   ┆ … ┆ unixRevie ┆ style     ┆ image     ┆ reviewer │
# │ D         ┆ ---       ┆ t         ┆ ---       ┆   ┆ wTime     ┆ ---       ┆ ---       ┆ Name     │
# │ ---       ┆ str       ┆ ---       ┆ str       ┆   ┆ ---       ┆ struct[1] ┆ list[str] ┆ ---      │
# │ str       ┆           ┆ str       ┆           ┆   ┆ i64       ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ AAP7PPBU7 ┆ 015100471 ┆ This is   ┆ A star is ┆ … ┆ 937612800 ┆ {" Hardco ┆ null      ┆ D. C.    │
# │ 2QFM      ┆ 4         ┆ the best  ┆ born      ┆   ┆           ┆ ver"}     ┆           ┆ Carrad   │
# │           ┆           ┆ novel I   ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ have …    ┆           ┆   ┆           ┆           ┆           ┆          │
# │ A2E168DTV ┆ 015100471 ┆ Pages and ┆ A stream  ┆ … ┆ 138248640 ┆ {" Kindle ┆ null      ┆ Evy      │
# │ GE6SV     ┆ 4         ┆ pages of  ┆ of consci ┆   ┆ 0         ┆ Edition"} ┆           ┆          │
# │           ┆           ┆ introspec ┆ ousness   ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ ti…       ┆ nove…     ┆   ┆           ┆           ┆           ┆          │
# │ A1ER5AYS3 ┆ 015100471 ┆ This is   ┆ I'm a     ┆ … ┆ 122031360 ┆ {" Paperb ┆ null      ┆ Kcorn    │
# │ FQ9O3     ┆ 4         ┆ the kind  ┆ huge fan  ┆   ┆ 0         ┆ ack"}     ┆           ┆          │
# │           ┆           ┆ of novel  ┆ of the    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ to r…     ┆ author a… ┆   ┆           ┆           ┆           ┆          │
# │ A1T17LMQA ┆ 015100471 ┆ What      ┆ The most  ┆ … ┆ 968025600 ┆ {" Hardco ┆ null      ┆ Caf Girl │
# │ BMBN5     ┆ 4         ┆ gorgeous  ┆ beautiful ┆   ┆           ┆ ver"}     ┆           ┆ Writes   │
# │           ┆           ┆ language! ┆ book I    ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ What a…   ┆ have…     ┆   ┆           ┆           ┆           ┆          │
# │ A3QHJ0FXK ┆ 015100471 ┆ I was     ┆ A dissent ┆ … ┆ 949622400 ┆ {" Hardco ┆ null      ┆ W. Shane │
# │ 33OBE     ┆ 4         ┆ taken in  ┆ ing       ┆   ┆           ┆ ver"}     ┆           ┆ Schmidt  │
# │           ┆           ┆ by        ┆ view--In  ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ reviews   ┆ part.     ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ that…     ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
#Dropping rows with missing fields
df = (
    df
    .filter(pl.col("asin").is_not_null())
    .filter(pl.col("reviewText").is_not_null())
)

# %%
#Rename columns
df = df.rename({
    "reviewerID": "reviewer_id",
    "asin": "product_id",
    "reviewText": "original_review",
    "summary": "user_summary",
    "overall": "rating",
    "vote": "helpful_votes",
    "verified": "is_verified",
    "reviewTime": "review_date",
    "unixReviewTime": "review_timestamp"
})

# %%
#Helpful votes
df = df.with_columns([
    pl.col("helpful_votes")
      .str.replace(",", "")
      .cast(pl.Int64, strict=False)
      .fill_null(0)
])

# %%
#Fill null summaries
df = df.with_columns([
    pl.col("user_summary")
      .fill_null("No summary provided")
])

# %%
#Flatten style metadata
# Flatten style metadata
df = df.with_columns([
    pl.col("style")
      .map_elements(lambda x: flatten_style(x))
      .alias("product_style")
])

# %%
#Clean review text
df = df.with_columns([
    pl.col("original_review")
      .map_elements(lambda x: clean_text(x))
      .alias("cleaned_review")
])

# %%
#Convert Dates & Timestamp
df = df.with_columns([
    pl.col("review_date")
      .str.to_date(format="%m %d, %Y", strict=False)
      .alias("review_date"),

    pl.col("review_timestamp").cast(pl.Int64)
])

# %%
#Drop useless columns
df = df.drop(["image", "reviewerName", "style"])

# %%
#Filtering short reviews
df = df.filter(pl.col("cleaned_review").str.len_chars() > 20)

# %%
#Filter products with fewer than 5 reviews
counts = (
    df
    .group_by("product_id")
    .count()
    .rename({"count": "review_count"})
)

df = df.join(counts, on="product_id")
df = df.filter(pl.col("review_count") >= 5)
# Out:
# /tmp/ipykernel_562/3383244658.py:6: DeprecationWarning: `GroupBy.count` was renamed; use `GroupBy.len` instead
#   .count()

# %%
#Save as CSV 
output_csv = "electronics_clean.csv"

df.to_pandas().to_csv(output_csv, index=False)

# Upload to S3
# !aws s3 cp electronics_clean.csv s3://amazon-electronics-dataset/Preprocessed_dataset/

print("Cleaned dataset uploaded to: s3://amazon-electronics-dataset/Preprocessed_dataset/")
# Out:
# upload: ./electronics_clean.csv to s3://amazon-electronics-dataset/Preprocessed_dataset/electronics_clean.csv
# Cleaned dataset uploaded to: s3://amazon-electronics-dataset/Preprocessed_dataset/
